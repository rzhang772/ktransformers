# %%
import random
from datasets import load_dataset

random.seed(42)  # 设置随机种子以确保结果可复现
# 下载 XSum 数据集的训练集
# 自然问答，文本摘要
xsum = load_dataset("xsum", split="train")
print(xsum)
trivaqa = load_dataset("mandarjoshi/trivia_qa", "rc.nocontext", split="train")
print(trivaqa)

# 数学推理
gsm8k = load_dataset("openai/gsm8k","main", split="train")
print(gsm8k)
# 代码能力
humaneval = load_dataset("openai/openai_humaneval", split="test")
print(humaneval)

# 多语言，翻译
xglue = load_dataset("gsarti/flores_101", "all", split="dev")
print(xglue)
# Out:
# Dataset({
#     features: ['document', 'summary', 'id'],
#     num_rows: 204045
# })
# Dataset({
#     features: ['question', 'question_id', 'question_source', 'entity_pages', 'search_results', 'answer'],
#     num_rows: 138384
# })
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 7473
# })
# Dataset({
#     features: ['task_id', 'prompt', 'canonical_solution', 'test', 'entry_point'],
#     num_rows: 164
# })
# Dataset({
#     features: ['id', 'URL', 'domain', 'topic', 'has_image', 'has_hyperlink', 'sentence_afr', 'sentence_amh', 'sentence_ara', 'sentence_hye', 'sentence_asm', 'sentence_ast', 'sentence_azj', 'sentence_bel', 'sentence_ben', 'sentence_bos', 'sentence_bul', 'sentence_mya', 'sentence_cat', 'sentence_ceb', 'sentence_zho_simpl', 'sentence_zho_trad', 'sentence_hrv', 'sentence_ces', 'sentence_dan', 'sentence_nld', 'sentence_eng', 'sentence_est', 'sentence_tgl', 'sentence_fin', 'sentence_fra', 'sentence_ful', 'sentence_glg', 'sentence_lug', 'sentence_kat', 'sentence_deu', 'sentence_ell', 'sentence_guj', 'sentence_hau', 'sentence_heb', 'sentence_hin', 'sentence_hun', 'sentence_isl', 'sentence_ibo', 'sentence_ind', 'sentence_gle', 'sentence_ita', 'sentence_jpn', 'sentence_jav', 'sentence_kea', 'sentence_kam', 'sentence_kan', 'sentence_kaz', 'sentence_khm', 'sentence_kor', 'sentence_kir', 'sentence_lao', 'sentence_lav', 'sentence_lin', 'sentence_lit', 'sentence_luo', 'sentence_ltz', 'sentence_mkd', 'sentence_msa', 'sentence_mal', 'sentence_mlt', 'sentence_mri', 'sentence_mar', 'sentence_mon', 'sentence_npi', 'sentence_nso', 'sentence_nob', 'sentence_nya', 'sentence_oci', 'sentence_ory', 'sentence_orm', 'sentence_pus', 'sentence_fas', 'sentence_pol', 'sentence_por', 'sentence_pan', 'sentence_ron', 'sentence_rus', 'sentence_srp', 'sentence_sna', 'sentence_snd', 'sentence_slk', 'sentence_slv', 'sentence_som', 'sentence_ckb', 'sentence_spa', 'sentence_swh', 'sentence_swe', 'sentence_tgk', 'sentence_tam', 'sentence_tel', 'sentence_tha', 'sentence_tur', 'sentence_ukr', 'sentence_umb', 'sentence_urd', 'sentence_uzb', 'sentence_vie', 'sentence_cym', 'sentence_wol', 'sentence_xho', 'sentence_yor', 'sentence_zul'],
#     num_rows: 997
# })

# %%
xsum_sample = random.sample(list(xsum), 100)
triviaqa_sample = random.sample(list(trivaqa), 100)
gsm8k_sample = random.sample(list(gsm8k), 100)
humaneval_sample = random.sample(list(humaneval), 100)
flores_sample = random.sample(list(xglue), 100)

# %%
xsum_sample[0]['document']
# Out:
# 'Private Harry Vasey, who was part of the 1st Airborne Battalion, The Border Regiment, was killed during Operation Market Garden in Oosterbeek in 1944.\nNow his identity has been confirmed, the Ministry of Defence (MoD) want to trace his family so his grave can be rededicated in the Netherlands.\nThe MoD said plans were also in place to change his headstone.\nBorn in Durham in May 1916 to Harry Vasey and Annie Young, he enlisted in April 1940 when he lived in Bowburn, County Durham.\nAn MoD spokesman said: "Unfortunately that is about all we know about Private Vasey and his family and that\'s where the trail goes cold.\n"We are hoping that there are some of his family still living in that area."\nSince WW2, a section of the Royal Netherlands Army has been working to identify the graves of unknown soldiers killed in battle.\nThe exhumation reports were scrutinised for clues to the identities of these men and the research was presented to the MoD.\nMr Vasey is one of six Border Regiment soldiers, including Lance Corporal Raymond Halliday, to be indentified.\nThe aim of Operation Market Garden was to take strategic bridges near Arnhem, but the Allies underestimated the number of German troops lying in wait and it failed.\nMore than 1,400 Allied troops died and more than 6,000 were captured by German forces.\nIt is hoped Mr Vasey\'s surviving relatives can attend the service at Oosterbeek Cemetery on 14 September in honour of his sacrifice and bravery, the MoD said.'

# %%
import os

import re

def sanitize_filename(name):
    """将非法文件名字符替换为下划线"""
    return re.sub(r'[\\/*?:"<>|]', '_', str(name))

# 保存函数
def save_text_samples(samples, key, name_fn, folder):
    os.makedirs(folder, exist_ok=True)
    for i, sample in enumerate(samples):
        file_id = name_fn(sample, i)
        file_id = sanitize_filename(file_id)
        with open(os.path.join(folder, f"{file_id}.txt"), "w", encoding="utf-8") as f:
            f.write(sample[key])

# 保存路径
base_dir = "./prompt_datasets"
paths = {
    "xsum": os.path.join(base_dir, "xsum"),
    "triviaqa": os.path.join(base_dir, "triviaqa"),
    "gsm8k": os.path.join(base_dir, "gsm8k"),
    "humaneval": os.path.join(base_dir, "humaneval"),
    "flores_101": os.path.join(base_dir, "flores_101"),
}

# 执行保存
save_text_samples(xsum_sample, "document", lambda s, i: s["id"], paths["xsum"])
save_text_samples(triviaqa_sample, "question", lambda s, i: s["question_id"], paths["triviaqa"])
save_text_samples(gsm8k_sample, "question", lambda s, i: str(i), paths["gsm8k"])
save_text_samples(humaneval_sample, "prompt", lambda s, i: s["task_id"], paths["humaneval"])
save_text_samples(flores_sample, "sentence_zho_simpl", lambda s, i: s["id"], paths["flores_101"])

# %%
import os

def list_prompt_files_by_dataset(base_dir="./prompt_datasets"):
    dataset_files = {}

    for dataset_name in os.listdir(base_dir):
        dataset_path = os.path.join(base_dir, dataset_name)
        if not os.path.isdir(dataset_path):
            continue

        files = []
        for filename in os.listdir(dataset_path):
            if filename.endswith(".txt"):
                file_path = os.path.join(dataset_path, filename)
                files.append(file_path)

        dataset_files[dataset_name] = sorted(files)  # 可选：排序方便查看

    return dataset_files

# 使用示例
files_by_dataset = list_prompt_files_by_dataset()

# 输出示例
for dataset, files in files_by_dataset.items():
    print(f"\n📂 Dataset: {dataset} ({len(files)} files)")
    for path in files:
        print(f"  - {path}")
# Out:
# 📂 Dataset: triviaqa (100 files)
#   - ./prompt_datasets/triviaqa/bb_1294.txt
#   - ./prompt_datasets/triviaqa/bb_4237.txt
#   - ./prompt_datasets/triviaqa/bb_5366.txt
#   - ./prompt_datasets/triviaqa/bb_5933.txt
#   - ./prompt_datasets/triviaqa/bb_6469.txt
#   - ./prompt_datasets/triviaqa/bt_1205.txt
#   - ./prompt_datasets/triviaqa/bt_1809.txt
#   - ./prompt_datasets/triviaqa/bt_1876.txt
#   - ./prompt_datasets/triviaqa/bt_2568.txt
#   - ./prompt_datasets/triviaqa/bt_2575.txt
#   - ./prompt_datasets/triviaqa/bt_2586.txt
#   - ./prompt_datasets/triviaqa/bt_3003.txt
#   - ./prompt_datasets/triviaqa/bt_3627.txt
#   - ./prompt_datasets/triviaqa/bt_3912.txt
#   - ./prompt_datasets/triviaqa/bt_923.txt
#   - ./prompt_datasets/triviaqa/dpql_3288.txt
#   - ./prompt_datasets/triviaqa/dpql_4065.txt
#   - ./prompt_datasets/triviaqa/dpql_4110.txt
#   - ./prompt_datasets/triviaqa/dpql_5185.txt
#   - ./prompt_datasets/triviaqa/dpql_6211.txt
#   - ./prompt_datasets/triviaqa/jp_1483.txt
#   - ./prompt_datasets/triviaqa/jp_1960.txt
#   - ./prompt_datasets/triviaqa/jp_3117.txt
#   - ./prompt_datasets/triviaqa/jp_70.txt
#   - ./prompt_datasets/triviaqa/jp_835.txt
#   - ./prompt_datasets/triviaqa/odql_10154.txt
#   - ./prompt_datasets/triviaqa/odql_10633.txt
#   - ./prompt_datasets/triviaqa/odql_11585.txt
#   - ./prompt_datasets/triviaqa/odql_13383.txt
#   - ./prompt_datasets/triviaqa/odql_13986.txt
#   - ./prompt_datasets/triviaqa/odql_1779.txt
#   - ./prompt_datasets/triviaqa/odql_2502.txt
#   - ./prompt_datasets/triviaqa/odql_2921.txt
#   - ./prompt_datasets/triviaqa/odql_6689.txt
#   - ./prompt_datasets/triviaqa/odql_6952.txt
#   - ./prompt_datasets/triviaqa/odql_7265.txt
#   - ./prompt_datasets/triviaqa/odql_748.txt
#   - ./prompt_datasets/triviaqa/odql_8223.txt
#   - ./prompt_datasets/triviaqa/odql_9629.txt
#   - ./prompt_datasets/triviaqa/qb_10178.txt
#   - ./prompt_datasets/triviaqa/qb_167.txt
#   - ./prompt_datasets/triviaqa/qb_2247.txt
#   - ./prompt_datasets/triviaqa/qb_3525.txt
#   - ./prompt_datasets/triviaqa/qb_371.txt
#   - ./prompt_datasets/triviaqa/qb_3870.txt
#   - ./prompt_datasets/triviaqa/qb_4760.txt
#   - ./prompt_datasets/triviaqa/qb_7662.txt
#   - ./prompt_datasets/triviaqa/qb_768.txt
#   - ./prompt_datasets/triviaqa/qb_7729.txt
#   - ./prompt_datasets/triviaqa/qf_3402.txt
#   - ./prompt_datasets/triviaqa/qg_4533.txt
#   - ./prompt_datasets/triviaqa/qw_10067.txt
#   - ./prompt_datasets/triviaqa/qw_12339.txt
#   - ./prompt_datasets/triviaqa/qw_13696.txt
#   - ./prompt_datasets/triviaqa/qw_14342.txt
#   - ./prompt_datasets/triviaqa/qw_1515.txt
#   - ./prompt_datasets/triviaqa/qw_16620.txt
#   - ./prompt_datasets/triviaqa/qw_1751.txt
#   - ./prompt_datasets/triviaqa/qw_3123.txt
#   - ./prompt_datasets/triviaqa/qw_4612.txt
#   - ./prompt_datasets/triviaqa/qw_4894.txt
#   - ./prompt_datasets/triviaqa/qw_5520.txt
#   - ./prompt_datasets/triviaqa/qw_5684.txt
#   - ./prompt_datasets/triviaqa/qw_6163.txt
#   - ./prompt_datasets/triviaqa/qw_7000.txt
#   - ./prompt_datasets/triviaqa/qw_8005.txt
#   - ./prompt_datasets/triviaqa/qz_1955.txt
#   - ./prompt_datasets/triviaqa/qz_271.txt
#   - ./prompt_datasets/triviaqa/sfq_11447.txt
#   - ./prompt_datasets/triviaqa/sfq_11738.txt
#   - ./prompt_datasets/triviaqa/sfq_12949.txt
#   - ./prompt_datasets/triviaqa/sfq_18858.txt
#   - ./prompt_datasets/triviaqa/sfq_19185.txt
#   - ./prompt_datasets/triviaqa/sfq_19837.txt
#   - ./prompt_datasets/triviaqa/sfq_19999.txt
#   - ./prompt_datasets/triviaqa/sfq_2107.txt
#   - ./prompt_datasets/triviaqa/sfq_2108.txt
#   - ./prompt_datasets/triviaqa/sfq_22164.txt
#   - ./prompt_datasets/triviaqa/sfq_23638.txt
#   - ./prompt_datasets/triviaqa/sfq_23731.txt
#   - ./prompt_datasets/triviaqa/sfq_23914.txt
#   - ./prompt_datasets/triviaqa/sfq_24224.txt
#   - ./prompt_datasets/triviaqa/sfq_26247.txt
#   - ./prompt_datasets/triviaqa/sfq_4087.txt
#   - ./prompt_datasets/triviaqa/sfq_4786.txt
#   - ./prompt_datasets/triviaqa/sfq_5394.txt
#   - ./prompt_datasets/triviaqa/sfq_5753.txt
#   - ./prompt_datasets/triviaqa/sfq_6179.txt
#   - ./prompt_datasets/triviaqa/sfq_6703.txt
#   - ./prompt_datasets/triviaqa/sfq_8546.txt
#   - ./prompt_datasets/triviaqa/tb_1005.txt
#   - ./prompt_datasets/triviaqa/tb_561.txt
#   - ./prompt_datasets/triviaqa/tb_715.txt
#   - ./prompt_datasets/triviaqa/tc_1019.txt
#   - ./prompt_datasets/triviaqa/tc_1412.txt
#   - ./prompt_datasets/triviaqa/tc_252.txt
#   - ./prompt_datasets/triviaqa/tc_2905.txt
#   - ./prompt_datasets/triviaqa/wh_2030.txt
#   - ./prompt_datasets/triviaqa/wh_28.txt
#   - ./prompt_datasets/triviaqa/wh_886.txt
#
# 📂 Dataset: xsum (100 files)
#   - ./prompt_datasets/xsum/13311206.txt
#   - ./prompt_datasets/xsum/18171442.txt
#   - ./prompt_datasets/xsum/21290761.txt
#   - ./prompt_datasets/xsum/21496997.txt
#   - ./prompt_datasets/xsum/22103472.txt
#   - ./prompt_datasets/xsum/22726902.txt
#   - ./prompt_datasets/xsum/25820223.txt
#   - ./prompt_datasets/xsum/28165048.txt
#   - ./prompt_datasets/xsum/28767650.txt
#   - ./prompt_datasets/xsum/28779493.txt
#   - ./prompt_datasets/xsum/29272732.txt
#   - ./prompt_datasets/xsum/29413435.txt
#   - ./prompt_datasets/xsum/29489290.txt
#   - ./prompt_datasets/xsum/30401529.txt
#   - ./prompt_datasets/xsum/30412293.txt
#   - ./prompt_datasets/xsum/30764794.txt
#   - ./prompt_datasets/xsum/30855311.txt
#   - ./prompt_datasets/xsum/30931237.txt
#   - ./prompt_datasets/xsum/31039493.txt
#   - ./prompt_datasets/xsum/31384442.txt
#   - ./prompt_datasets/xsum/31518717.txt
#   - ./prompt_datasets/xsum/31766015.txt
#   - ./prompt_datasets/xsum/32222520.txt
#   - ./prompt_datasets/xsum/32333596.txt
#   - ./prompt_datasets/xsum/32606371.txt
#   - ./prompt_datasets/xsum/33023204.txt
#   - ./prompt_datasets/xsum/33049482.txt
#   - ./prompt_datasets/xsum/33182392.txt
#   - ./prompt_datasets/xsum/33210019.txt
#   - ./prompt_datasets/xsum/33238562.txt
#   - ./prompt_datasets/xsum/33691355.txt
#   - ./prompt_datasets/xsum/33706475.txt
#   - ./prompt_datasets/xsum/33738163.txt
#   - ./prompt_datasets/xsum/34150322.txt
#   - ./prompt_datasets/xsum/34288870.txt
#   - ./prompt_datasets/xsum/34378804.txt
#   - ./prompt_datasets/xsum/34537135.txt
#   - ./prompt_datasets/xsum/34553332.txt
#   - ./prompt_datasets/xsum/34781257.txt
#   - ./prompt_datasets/xsum/34908126.txt
#   - ./prompt_datasets/xsum/34982620.txt
#   - ./prompt_datasets/xsum/35025346.txt
#   - ./prompt_datasets/xsum/35061463.txt
#   - ./prompt_datasets/xsum/35092649.txt
#   - ./prompt_datasets/xsum/35159599.txt
#   - ./prompt_datasets/xsum/35186942.txt
#   - ./prompt_datasets/xsum/35232680.txt
#   - ./prompt_datasets/xsum/35249044.txt
#   - ./prompt_datasets/xsum/35447704.txt
#   - ./prompt_datasets/xsum/35491406.txt
#   - ./prompt_datasets/xsum/35621444.txt
#   - ./prompt_datasets/xsum/35873525.txt
#   - ./prompt_datasets/xsum/36052686.txt
#   - ./prompt_datasets/xsum/36158916.txt
#   - ./prompt_datasets/xsum/36424239.txt
#   - ./prompt_datasets/xsum/36642237.txt
#   - ./prompt_datasets/xsum/36802710.txt
#   - ./prompt_datasets/xsum/36851562.txt
#   - ./prompt_datasets/xsum/36936149.txt
#   - ./prompt_datasets/xsum/36968995.txt
#   - ./prompt_datasets/xsum/37031651.txt
#   - ./prompt_datasets/xsum/37188256.txt
#   - ./prompt_datasets/xsum/37227308.txt
#   - ./prompt_datasets/xsum/37230012.txt
#   - ./prompt_datasets/xsum/37300470.txt
#   - ./prompt_datasets/xsum/37307169.txt
#   - ./prompt_datasets/xsum/37481606.txt
#   - ./prompt_datasets/xsum/37510253.txt
#   - ./prompt_datasets/xsum/37888387.txt
#   - ./prompt_datasets/xsum/37929842.txt
#   - ./prompt_datasets/xsum/38082444.txt
#   - ./prompt_datasets/xsum/38146988.txt
#   - ./prompt_datasets/xsum/38224430.txt
#   - ./prompt_datasets/xsum/38272960.txt
#   - ./prompt_datasets/xsum/38306960.txt
#   - ./prompt_datasets/xsum/38307773.txt
#   - ./prompt_datasets/xsum/38411440.txt
#   - ./prompt_datasets/xsum/38448361.txt
#   - ./prompt_datasets/xsum/38581789.txt
#   - ./prompt_datasets/xsum/38677416.txt
#   - ./prompt_datasets/xsum/38809056.txt
#   - ./prompt_datasets/xsum/38819783.txt
#   - ./prompt_datasets/xsum/38954295.txt
#   - ./prompt_datasets/xsum/39023300.txt
#   - ./prompt_datasets/xsum/39068035.txt
#   - ./prompt_datasets/xsum/39290592.txt
#   - ./prompt_datasets/xsum/39367770.txt
#   - ./prompt_datasets/xsum/39648271.txt
#   - ./prompt_datasets/xsum/39667912.txt
#   - ./prompt_datasets/xsum/39751666.txt
#   - ./prompt_datasets/xsum/39827457.txt
#   - ./prompt_datasets/xsum/39868518.txt
#   - ./prompt_datasets/xsum/39947993.txt
#   - ./prompt_datasets/xsum/40011837.txt
#   - ./prompt_datasets/xsum/40012707.txt
#   - ./prompt_datasets/xsum/40027223.txt
#   - ./prompt_datasets/xsum/40237819.txt
#   - ./prompt_datasets/xsum/40318885.txt
#   - ./prompt_datasets/xsum/40898320.txt
#   - ./prompt_datasets/xsum/41047208.txt
#
# 📂 Dataset: gsm8k (100 files)
#   - ./prompt_datasets/gsm8k/0.txt
#   - ./prompt_datasets/gsm8k/1.txt
#   - ./prompt_datasets/gsm8k/10.txt
#   - ./prompt_datasets/gsm8k/11.txt
#   - ./prompt_datasets/gsm8k/12.txt
#   - ./prompt_datasets/gsm8k/13.txt
#   - ./prompt_datasets/gsm8k/14.txt
#   - ./prompt_datasets/gsm8k/15.txt
#   - ./prompt_datasets/gsm8k/16.txt
#   - ./prompt_datasets/gsm8k/17.txt
#   - ./prompt_datasets/gsm8k/18.txt
#   - ./prompt_datasets/gsm8k/19.txt
#   - ./prompt_datasets/gsm8k/2.txt
#   - ./prompt_datasets/gsm8k/20.txt
#   - ./prompt_datasets/gsm8k/21.txt
#   - ./prompt_datasets/gsm8k/22.txt
#   - ./prompt_datasets/gsm8k/23.txt
#   - ./prompt_datasets/gsm8k/24.txt
#   - ./prompt_datasets/gsm8k/25.txt
#   - ./prompt_datasets/gsm8k/26.txt
#   - ./prompt_datasets/gsm8k/27.txt
#   - ./prompt_datasets/gsm8k/28.txt
#   - ./prompt_datasets/gsm8k/29.txt
#   - ./prompt_datasets/gsm8k/3.txt
#   - ./prompt_datasets/gsm8k/30.txt
#   - ./prompt_datasets/gsm8k/31.txt
#   - ./prompt_datasets/gsm8k/32.txt
#   - ./prompt_datasets/gsm8k/33.txt
#   - ./prompt_datasets/gsm8k/34.txt
#   - ./prompt_datasets/gsm8k/35.txt
#   - ./prompt_datasets/gsm8k/36.txt
#   - ./prompt_datasets/gsm8k/37.txt
#   - ./prompt_datasets/gsm8k/38.txt
#   - ./prompt_datasets/gsm8k/39.txt
#   - ./prompt_datasets/gsm8k/4.txt
#   - ./prompt_datasets/gsm8k/40.txt
#   - ./prompt_datasets/gsm8k/41.txt
#   - ./prompt_datasets/gsm8k/42.txt
#   - ./prompt_datasets/gsm8k/43.txt
#   - ./prompt_datasets/gsm8k/44.txt
#   - ./prompt_datasets/gsm8k/45.txt
#   - ./prompt_datasets/gsm8k/46.txt
#   - ./prompt_datasets/gsm8k/47.txt
#   - ./prompt_datasets/gsm8k/48.txt
#   - ./prompt_datasets/gsm8k/49.txt
#   - ./prompt_datasets/gsm8k/5.txt
#   - ./prompt_datasets/gsm8k/50.txt
#   - ./prompt_datasets/gsm8k/51.txt
#   - ./prompt_datasets/gsm8k/52.txt
#   - ./prompt_datasets/gsm8k/53.txt
#   - ./prompt_datasets/gsm8k/54.txt
#   - ./prompt_datasets/gsm8k/55.txt
#   - ./prompt_datasets/gsm8k/56.txt
#   - ./prompt_datasets/gsm8k/57.txt
#   - ./prompt_datasets/gsm8k/58.txt
#   - ./prompt_datasets/gsm8k/59.txt
#   - ./prompt_datasets/gsm8k/6.txt
#   - ./prompt_datasets/gsm8k/60.txt
#   - ./prompt_datasets/gsm8k/61.txt
#   - ./prompt_datasets/gsm8k/62.txt
#   - ./prompt_datasets/gsm8k/63.txt
#   - ./prompt_datasets/gsm8k/64.txt
#   - ./prompt_datasets/gsm8k/65.txt
#   - ./prompt_datasets/gsm8k/66.txt
#   - ./prompt_datasets/gsm8k/67.txt
#   - ./prompt_datasets/gsm8k/68.txt
#   - ./prompt_datasets/gsm8k/69.txt
#   - ./prompt_datasets/gsm8k/7.txt
#   - ./prompt_datasets/gsm8k/70.txt
#   - ./prompt_datasets/gsm8k/71.txt
#   - ./prompt_datasets/gsm8k/72.txt
#   - ./prompt_datasets/gsm8k/73.txt
#   - ./prompt_datasets/gsm8k/74.txt
#   - ./prompt_datasets/gsm8k/75.txt
#   - ./prompt_datasets/gsm8k/76.txt
#   - ./prompt_datasets/gsm8k/77.txt
#   - ./prompt_datasets/gsm8k/78.txt
#   - ./prompt_datasets/gsm8k/79.txt
#   - ./prompt_datasets/gsm8k/8.txt
#   - ./prompt_datasets/gsm8k/80.txt
#   - ./prompt_datasets/gsm8k/81.txt
#   - ./prompt_datasets/gsm8k/82.txt
#   - ./prompt_datasets/gsm8k/83.txt
#   - ./prompt_datasets/gsm8k/84.txt
#   - ./prompt_datasets/gsm8k/85.txt
#   - ./prompt_datasets/gsm8k/86.txt
#   - ./prompt_datasets/gsm8k/87.txt
#   - ./prompt_datasets/gsm8k/88.txt
#   - ./prompt_datasets/gsm8k/89.txt
#   - ./prompt_datasets/gsm8k/9.txt
#   - ./prompt_datasets/gsm8k/90.txt
#   - ./prompt_datasets/gsm8k/91.txt
#   - ./prompt_datasets/gsm8k/92.txt
#   - ./prompt_datasets/gsm8k/93.txt
#   - ./prompt_datasets/gsm8k/94.txt
#   - ./prompt_datasets/gsm8k/95.txt
#   - ./prompt_datasets/gsm8k/96.txt
#   - ./prompt_datasets/gsm8k/97.txt
#   - ./prompt_datasets/gsm8k/98.txt
#   - ./prompt_datasets/gsm8k/99.txt
#
# 📂 Dataset: humaneval (100 files)
#   - ./prompt_datasets/humaneval/HumanEval_0.txt
#   - ./prompt_datasets/humaneval/HumanEval_1.txt
#   - ./prompt_datasets/humaneval/HumanEval_10.txt
#   - ./prompt_datasets/humaneval/HumanEval_101.txt
#   - ./prompt_datasets/humaneval/HumanEval_103.txt
#   - ./prompt_datasets/humaneval/HumanEval_107.txt
#   - ./prompt_datasets/humaneval/HumanEval_108.txt
#   - ./prompt_datasets/humaneval/HumanEval_11.txt
#   - ./prompt_datasets/humaneval/HumanEval_116.txt
#   - ./prompt_datasets/humaneval/HumanEval_117.txt
#   - ./prompt_datasets/humaneval/HumanEval_118.txt
#   - ./prompt_datasets/humaneval/HumanEval_119.txt
#   - ./prompt_datasets/humaneval/HumanEval_12.txt
#   - ./prompt_datasets/humaneval/HumanEval_121.txt
#   - ./prompt_datasets/humaneval/HumanEval_122.txt
#   - ./prompt_datasets/humaneval/HumanEval_124.txt
#   - ./prompt_datasets/humaneval/HumanEval_125.txt
#   - ./prompt_datasets/humaneval/HumanEval_127.txt
#   - ./prompt_datasets/humaneval/HumanEval_128.txt
#   - ./prompt_datasets/humaneval/HumanEval_13.txt
#   - ./prompt_datasets/humaneval/HumanEval_130.txt
#   - ./prompt_datasets/humaneval/HumanEval_132.txt
#   - ./prompt_datasets/humaneval/HumanEval_133.txt
#   - ./prompt_datasets/humaneval/HumanEval_134.txt
#   - ./prompt_datasets/humaneval/HumanEval_135.txt
#   - ./prompt_datasets/humaneval/HumanEval_138.txt
#   - ./prompt_datasets/humaneval/HumanEval_14.txt
#   - ./prompt_datasets/humaneval/HumanEval_140.txt
#   - ./prompt_datasets/humaneval/HumanEval_141.txt
#   - ./prompt_datasets/humaneval/HumanEval_142.txt
#   - ./prompt_datasets/humaneval/HumanEval_143.txt
#   - ./prompt_datasets/humaneval/HumanEval_145.txt
#   - ./prompt_datasets/humaneval/HumanEval_146.txt
#   - ./prompt_datasets/humaneval/HumanEval_148.txt
#   - ./prompt_datasets/humaneval/HumanEval_149.txt
#   - ./prompt_datasets/humaneval/HumanEval_15.txt
#   - ./prompt_datasets/humaneval/HumanEval_150.txt
#   - ./prompt_datasets/humaneval/HumanEval_151.txt
#   - ./prompt_datasets/humaneval/HumanEval_152.txt
#   - ./prompt_datasets/humaneval/HumanEval_153.txt
#   - ./prompt_datasets/humaneval/HumanEval_157.txt
#   - ./prompt_datasets/humaneval/HumanEval_16.txt
#   - ./prompt_datasets/humaneval/HumanEval_162.txt
#   - ./prompt_datasets/humaneval/HumanEval_163.txt
#   - ./prompt_datasets/humaneval/HumanEval_17.txt
#   - ./prompt_datasets/humaneval/HumanEval_19.txt
#   - ./prompt_datasets/humaneval/HumanEval_20.txt
#   - ./prompt_datasets/humaneval/HumanEval_26.txt
#   - ./prompt_datasets/humaneval/HumanEval_27.txt
#   - ./prompt_datasets/humaneval/HumanEval_30.txt
#   - ./prompt_datasets/humaneval/HumanEval_31.txt
#   - ./prompt_datasets/humaneval/HumanEval_32.txt
#   - ./prompt_datasets/humaneval/HumanEval_33.txt
#   - ./prompt_datasets/humaneval/HumanEval_34.txt
#   - ./prompt_datasets/humaneval/HumanEval_35.txt
#   - ./prompt_datasets/humaneval/HumanEval_36.txt
#   - ./prompt_datasets/humaneval/HumanEval_38.txt
#   - ./prompt_datasets/humaneval/HumanEval_39.txt
#   - ./prompt_datasets/humaneval/HumanEval_40.txt
#   - ./prompt_datasets/humaneval/HumanEval_42.txt
#   - ./prompt_datasets/humaneval/HumanEval_43.txt
#   - ./prompt_datasets/humaneval/HumanEval_44.txt
#   - ./prompt_datasets/humaneval/HumanEval_47.txt
#   - ./prompt_datasets/humaneval/HumanEval_48.txt
#   - ./prompt_datasets/humaneval/HumanEval_5.txt
#   - ./prompt_datasets/humaneval/HumanEval_50.txt
#   - ./prompt_datasets/humaneval/HumanEval_52.txt
#   - ./prompt_datasets/humaneval/HumanEval_54.txt
#   - ./prompt_datasets/humaneval/HumanEval_55.txt
#   - ./prompt_datasets/humaneval/HumanEval_56.txt
#   - ./prompt_datasets/humaneval/HumanEval_58.txt
#   - ./prompt_datasets/humaneval/HumanEval_6.txt
#   - ./prompt_datasets/humaneval/HumanEval_60.txt
#   - ./prompt_datasets/humaneval/HumanEval_61.txt
#   - ./prompt_datasets/humaneval/HumanEval_62.txt
#   - ./prompt_datasets/humaneval/HumanEval_63.txt
#   - ./prompt_datasets/humaneval/HumanEval_64.txt
#   - ./prompt_datasets/humaneval/HumanEval_66.txt
#   - ./prompt_datasets/humaneval/HumanEval_67.txt
#   - ./prompt_datasets/humaneval/HumanEval_68.txt
#   - ./prompt_datasets/humaneval/HumanEval_69.txt
#   - ./prompt_datasets/humaneval/HumanEval_70.txt
#   - ./prompt_datasets/humaneval/HumanEval_72.txt
#   - ./prompt_datasets/humaneval/HumanEval_75.txt
#   - ./prompt_datasets/humaneval/HumanEval_77.txt
#   - ./prompt_datasets/humaneval/HumanEval_78.txt
#   - ./prompt_datasets/humaneval/HumanEval_79.txt
#   - ./prompt_datasets/humaneval/HumanEval_8.txt
#   - ./prompt_datasets/humaneval/HumanEval_80.txt
#   - ./prompt_datasets/humaneval/HumanEval_82.txt
#   - ./prompt_datasets/humaneval/HumanEval_83.txt
#   - ./prompt_datasets/humaneval/HumanEval_84.txt
#   - ./prompt_datasets/humaneval/HumanEval_85.txt
#   - ./prompt_datasets/humaneval/HumanEval_87.txt
#   - ./prompt_datasets/humaneval/HumanEval_9.txt
#   - ./prompt_datasets/humaneval/HumanEval_90.txt
#   - ./prompt_datasets/humaneval/HumanEval_91.txt
#   - ./prompt_datasets/humaneval/HumanEval_95.txt
#   - ./prompt_datasets/humaneval/HumanEval_96.txt
#   - ./prompt_datasets/humaneval/HumanEval_97.txt
#
# 📂 Dataset: flores_101 (100 files)
#   - ./prompt_datasets/flores_101/10.txt
#   - ./prompt_datasets/flores_101/106.txt
#   - ./prompt_datasets/flores_101/111.txt
#   - ./prompt_datasets/flores_101/115.txt
#   - ./prompt_datasets/flores_101/131.txt
#   - ./prompt_datasets/flores_101/134.txt
#   - ./prompt_datasets/flores_101/152.txt
#   - ./prompt_datasets/flores_101/153.txt
#   - ./prompt_datasets/flores_101/159.txt
#   - ./prompt_datasets/flores_101/164.txt
#   - ./prompt_datasets/flores_101/166.txt
#   - ./prompt_datasets/flores_101/167.txt
#   - ./prompt_datasets/flores_101/182.txt
#   - ./prompt_datasets/flores_101/184.txt
#   - ./prompt_datasets/flores_101/198.txt
#   - ./prompt_datasets/flores_101/205.txt
#   - ./prompt_datasets/flores_101/216.txt
#   - ./prompt_datasets/flores_101/228.txt
#   - ./prompt_datasets/flores_101/229.txt
#   - ./prompt_datasets/flores_101/234.txt
#   - ./prompt_datasets/flores_101/243.txt
#   - ./prompt_datasets/flores_101/25.txt
#   - ./prompt_datasets/flores_101/255.txt
#   - ./prompt_datasets/flores_101/256.txt
#   - ./prompt_datasets/flores_101/26.txt
#   - ./prompt_datasets/flores_101/269.txt
#   - ./prompt_datasets/flores_101/274.txt
#   - ./prompt_datasets/flores_101/286.txt
#   - ./prompt_datasets/flores_101/313.txt
#   - ./prompt_datasets/flores_101/316.txt
#   - ./prompt_datasets/flores_101/337.txt
#   - ./prompt_datasets/flores_101/341.txt
#   - ./prompt_datasets/flores_101/359.txt
#   - ./prompt_datasets/flores_101/363.txt
#   - ./prompt_datasets/flores_101/367.txt
#   - ./prompt_datasets/flores_101/37.txt
#   - ./prompt_datasets/flores_101/374.txt
#   - ./prompt_datasets/flores_101/379.txt
#   - ./prompt_datasets/flores_101/392.txt
#   - ./prompt_datasets/flores_101/40.txt
#   - ./prompt_datasets/flores_101/409.txt
#   - ./prompt_datasets/flores_101/41.txt
#   - ./prompt_datasets/flores_101/417.txt
#   - ./prompt_datasets/flores_101/422.txt
#   - ./prompt_datasets/flores_101/423.txt
#   - ./prompt_datasets/flores_101/43.txt
#   - ./prompt_datasets/flores_101/438.txt
#   - ./prompt_datasets/flores_101/441.txt
#   - ./prompt_datasets/flores_101/453.txt
#   - ./prompt_datasets/flores_101/472.txt
#   - ./prompt_datasets/flores_101/482.txt
#   - ./prompt_datasets/flores_101/559.txt
#   - ./prompt_datasets/flores_101/565.txt
#   - ./prompt_datasets/flores_101/566.txt
#   - ./prompt_datasets/flores_101/574.txt
#   - ./prompt_datasets/flores_101/575.txt
#   - ./prompt_datasets/flores_101/597.txt
#   - ./prompt_datasets/flores_101/636.txt
#   - ./prompt_datasets/flores_101/653.txt
#   - ./prompt_datasets/flores_101/676.txt
#   - ./prompt_datasets/flores_101/683.txt
#   - ./prompt_datasets/flores_101/686.txt
#   - ./prompt_datasets/flores_101/699.txt
#   - ./prompt_datasets/flores_101/708.txt
#   - ./prompt_datasets/flores_101/719.txt
#   - ./prompt_datasets/flores_101/723.txt
#   - ./prompt_datasets/flores_101/753.txt
#   - ./prompt_datasets/flores_101/755.txt
#   - ./prompt_datasets/flores_101/760.txt
#   - ./prompt_datasets/flores_101/768.txt
#   - ./prompt_datasets/flores_101/78.txt
#   - ./prompt_datasets/flores_101/790.txt
#   - ./prompt_datasets/flores_101/799.txt
#   - ./prompt_datasets/flores_101/802.txt
#   - ./prompt_datasets/flores_101/807.txt
#   - ./prompt_datasets/flores_101/815.txt
#   - ./prompt_datasets/flores_101/816.txt
#   - ./prompt_datasets/flores_101/820.txt
#   - ./prompt_datasets/flores_101/822.txt
#   - ./prompt_datasets/flores_101/831.txt
#   - ./prompt_datasets/flores_101/837.txt
#   - ./prompt_datasets/flores_101/841.txt
#   - ./prompt_datasets/flores_101/855.txt
#   - ./prompt_datasets/flores_101/880.txt
#   - ./prompt_datasets/flores_101/882.txt
#   - ./prompt_datasets/flores_101/885.txt
#   - ./prompt_datasets/flores_101/886.txt
#   - ./prompt_datasets/flores_101/893.txt
#   - ./prompt_datasets/flores_101/894.txt
#   - ./prompt_datasets/flores_101/896.txt
#   - ./prompt_datasets/flores_101/903.txt
#   - ./prompt_datasets/flores_101/905.txt
#   - ./prompt_datasets/flores_101/906.txt
#   - ./prompt_datasets/flores_101/921.txt
#   - ./prompt_datasets/flores_101/926.txt
#   - ./prompt_datasets/flores_101/941.txt
#   - ./prompt_datasets/flores_101/944.txt
#   - ./prompt_datasets/flores_101/956.txt
#   - ./prompt_datasets/flores_101/966.txt
#   - ./prompt_datasets/flores_101/968.txt
